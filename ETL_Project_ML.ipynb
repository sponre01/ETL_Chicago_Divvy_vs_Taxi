# %% [markdown]
# # Extract

# %% [markdown]
# - When: Analysis Timeframe: Fiscal Year 09-2016 to 08-2017
#
# - What: Divvy Trips Data
#
# - How (link): https://www.divvybikes.com/system-data
#
# - How (cvs_files from the following zips located on link page above): 2016 Q3 & Q4 DATA; 2017 Q1 & Q2 DATA; 2017 Q3 & Q4 DATA

# %% [markdown]
# ### Here is the web page screen shot

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Extract Coding Steps
# - Import Dependencies and Setup. Use Pandas and Numpy libraries.
# - Read each Divvy Data File and store into Pandas DataFrame

# %%
# Import Dependencies and Setup

import pandas as pd
import numpy as np

# %%
# Extract Divvy CSV Files

Divvy_Trips_2017_Q4_file = "Divvy_Trips_2017_Q4.csv"
Divvy_Trips_2017_Q3_file = "Divvy_Trips_2017_Q3.csv"
Divvy_Trips_2017_Q2_file = "Divvy_Trips_2017_Q2.csv"
Divvy_Trips_2017_Q1_file = "Divvy_Trips_2017_Q1.csv"
Divvy_Trips_2016_Q4_file = "Divvy_Trips_2016_Q4.csv"
Divvy_Trips_2016_Q3_file = "Divvy_Trips_2016_Q3.csv"
Divvy_Stations_2017_Q3Q4_file = "Divvy_Stations_2017_Q3Q4.csv"
Divvy_Stations_2017_Q1Q2_file = "Divvy_Stations_2017_Q3Q4.csv"
Divvy_Stations_2016_Q4_file = "Divvy_Stations_2016_Q4.csv"
Divvy_Stations_2016_Q3_file = "Divvy_Stations_2016_Q3.csv"

# %% [markdown]
# # Transform

# %% [markdown]
# ### Transform coding steps
#
# - Read each Divvy Data File and store into Pandas DataFrame
#
# - Combine Trips Divvy Data File and store into Pandas DataFrame
#
# - Print dataframe to assess number of rows and gage general integrity of the data
#
# - Assess the data and drop the columns that might not be relevant to final analysis.
#
#  - For this scenario (v. Taxis) we dropped the following: 'starttime','end_time','stoptime','start_time', 'gender','birthyear'

# %%
# Read each Divvy Data File and store into Pandas DataFrame

Divvy_Trips_2017_Q4_df = pd.read_csv(Divvy_Trips_2017_Q4_file)
Divvy_Trips_2017_Q3_df = pd.read_csv(Divvy_Trips_2017_Q3_file)
Divvy_Trips_2017_Q2_df = pd.read_csv(Divvy_Trips_2017_Q2_file)
Divvy_Trips_2017_Q1_df = pd.read_csv(Divvy_Trips_2017_Q1_file)
Divvy_Trips_2016_Q4_df = pd.read_csv(Divvy_Trips_2016_Q4_file)
Divvy_Trips_2016_Q3_df = pd.read_csv(Divvy_Trips_2016_Q3_file)

Divvy_Stations_2017_Q3Q4_df = pd.read_csv(Divvy_Stations_2017_Q3Q4_file)
Divvy_Stations_2017_Q1Q2_df = pd.read_csv(Divvy_Stations_2017_Q1Q2_file)
Divvy_Stations_2016_Q4_df = pd.read_csv(Divvy_Stations_2016_Q4_file)
Divvy_Stations_2016_Q3_df = pd.read_csv(Divvy_Stations_2016_Q3_file)

# %%
# Combine Trips Divvy Data File and store into Pandas DataFrame

Divvy_Trips_2017_Q3Q4_df = Divvy_Trips_2017_Q4_df.append(Divvy_Trips_2017_Q3_df)
Divvy_Trips_2017_Q2Q3Q4_df = Divvy_Trips_2017_Q3Q4_df.append(Divvy_Trips_2017_Q2_df)
Divvy_Trips_2017_df = Divvy_Trips_2017_Q2Q3Q4_df.append(Divvy_Trips_2017_Q1_df)
#Divvy_Trips_2017_df.head()
Divvy_Trips_2016_df = Divvy_Trips_2016_Q3_df.append(Divvy_Trips_2016_Q4_df)
Divvy_Trips_df = Divvy_Trips_2017_df.append(Divvy_Trips_2016_df)
Divvy_Trips_df.head()
# Out:
# /Users/michelelodl/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#    bikeid  birthyear          end_time  from_station_id  \
# 0    3304     1988.0     1/1/2018 0:03              159
# 1    5975        NaN     1/1/2018 0:18              145
# 2    4906        NaN     1/1/2018 0:18              145
# 3    5667     1963.0  12/31/2017 23:53              340
# 4    5353     1977.0  12/31/2017 23:47              240
#
#                      from_station_name gender        start_time starttime  \
# 0            Claremont Ave & Hirsch St   Male  12/31/2017 23:58       NaN
# 1  Mies van der Rohe Way & Chestnut St    NaN  12/31/2017 23:54       NaN
# ...

# %%
# Print dataframe to assess number of rows and gage general integrity of the data

Divvy_Trips_df
# Out:
#         bikeid  birthyear          end_time  from_station_id  \
# 0         3304     1988.0     1/1/2018 0:03              159
# 1         5975        NaN     1/1/2018 0:18              145
# 2         4906        NaN     1/1/2018 0:18              145
# 3         5667     1963.0  12/31/2017 23:53              340
# 4         5353     1977.0  12/31/2017 23:47              240
# 5         5840     1988.0  12/31/2017 23:51               93
# 6         6351     1990.0  12/31/2017 23:39              337
# 7         2562     1987.0  12/31/2017 23:23              226
# 8         2471     1981.0  12/31/2017 23:27               49
# 9         6462     1980.0  12/31/2017 23:09              196
# 10        3775     1991.0  12/31/2017 22:53               59
# 11        3663     1990.0  12/31/2017 22:53               59
# 12        6456     1991.0  12/31/2017 22:55              475
# 13        5529     1986.0  12/31/2017 22:51               67
# ...

# %%
# Assess the data and drop the columns that might not be relevant to final analysis.
# For this scenario (v. Taxis) we dropped the following: 'starttime','end_time','stoptime','start_time', 'gender','birthyear'

Divvy_Trips_df = Divvy_Trips_df.drop(columns=['starttime','end_time','stoptime','start_time','gender','birthyear'])

# %%
Divvy_Trips_df.head()
# Out:
#    bikeid  from_station_id                    from_station_name  \
# 0    3304              159            Claremont Ave & Hirsch St
# 1    5975              145  Mies van der Rohe Way & Chestnut St
# 2    4906              145  Mies van der Rohe Way & Chestnut St
# 3    5667              340            Clark St & Wrightwood Ave
# 4    5353              240         Sheridan Rd & Irving Park Rd
#
#    to_station_id                      to_station_name   trip_id  tripduration  \
# 0             69               Damen Ave & Pierce Ave  17536701           284
# 1            145  Mies van der Rohe Way & Chestnut St  17536700          1402
# 2            145  Mies van der Rohe Way & Chestnut St  17536699          1441
# 3            143            Sedgwick St & Webster Ave  17536698           315
# 4            245           Clarendon Ave & Junior Ter  17536697           272
#
#      usertype
# 0  Subscriber
# 1    Customer
# 2    Customer
# 3  Subscriber
# 4  Subscriber

# %%
cols = list(Divvy_Trips_df.columns.values)
cols
# Out:
# ['bikeid',
#  'from_station_id',
#  'from_station_name',
#  'to_station_id',
#  'to_station_name',
#  'trip_id',
#  'tripduration',
#  'usertype']

# %%
Divvy_Trips_df = Divvy_Trips_df[['from_station_id','to_station_id','trip_id','from_station_name','to_station_name','tripduration','usertype','bikeid']]
Divvy_Trips_df.head()
# Out:
#    from_station_id  to_station_id   trip_id  \
# 0              159             69  17536701
# 1              145            145  17536700
# 2              145            145  17536699
# 3              340            143  17536698
# 4              240            245  17536697
#
#                      from_station_name                      to_station_name  \
# 0            Claremont Ave & Hirsch St               Damen Ave & Pierce Ave
# 1  Mies van der Rohe Way & Chestnut St  Mies van der Rohe Way & Chestnut St
# 2  Mies van der Rohe Way & Chestnut St  Mies van der Rohe Way & Chestnut St
# 3            Clark St & Wrightwood Ave            Sedgwick St & Webster Ave
# 4         Sheridan Rd & Irving Park Rd           Clarendon Ave & Junior Ter
#
#    tripduration    usertype  bikeid
# 0           284  Subscriber    3304
# 1          1402    Customer    5975
# 2          1441    Customer    4906
# 3           315  Subscriber    5667
# 4           272  Subscriber    5353

# %%
Divvy_Trips_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5954657 entries, 0 to 683831
# Data columns (total 8 columns):
# from_station_id      int64
# to_station_id        int64
# trip_id              int64
# from_station_name    object
# to_station_name      object
# tripduration         int64
# usertype             object
# bikeid               int64
# dtypes: int64(5), object(3)
# memory usage: 408.9+ MB

# %% [markdown]
# # Load

# %% [markdown]
# ### Code to Load data
#
# - Upload the df into the Mongo Database. This is a way to store the data in a cloud. (If you receive and error, you may need to intall dnspython to connect.)
#
# - We are using a cloud-based database (hosted by cloud.mongodb.com) so nobody needs to store this locally
#
# - Import pymongo allows to use python to connect to a Mongo DB database
#
# - Establish a connection to the database
#
# - Create a client connecting to the database. This allows data to be loaded from python into the database
#
# - Establish a database in Mongo DB
#
# - Convert the Pandas DataFrame to a dictonary to be uploaded into Mongo DB
#
# - Insert the data into the Mongo DB database

# %%
# !pip install --upgrade pip
# Out:
# Requirement already up-to-date: pip in /Users/michelelodl/anaconda3/lib/python3.7/site-packages (19.0.3)

# %%
# !pip install dnspython

# %%
# Import pymongo allows to use python to connect to a Mongo DB database

import pymongo

# %%
# Establish a connection to the database

conn = 'mongodb+srv://test:test123@cluster0-xdqxx.mongodb.net/test?retryWrites=true'

# %%
# Create a client connecting to the database. This allows data to be loaded from python into the database

client = pymongo.MongoClient(conn)

# %%
# Establish a database in Mongo DB

db = client.divvy_taxi_db

# %%
# Convert the Pandas DataFrame to a dictonary to be uploaded into Mongo DB
# FYI: This toook about one minute for the 5 Million rows 

data = Divvy_Trips_df.to_dict(orient='records')

# %%
# Insert the data into the Mongo DB database. NOTE: This took 20 min to load 
db.Divvy_Trips.insert_many(data)

# %%
#Test to make sure there is data in the database

for i in db.Divvy_Trips.find({'bikeid':3304}):
    print(i)
# Out:
# {'_id': ObjectId('5c6e071c79ec420f7df9281a'), 'from_station_id': 159, 'to_station_id': 69, 'trip_id': 17536701, 'from_station_name': 'Claremont Ave & Hirsch St', 'to_station_name': 'Damen Ave & Pierce Ave', 'tripduration': 284, 'usertype': 'Subscriber', 'bikeid': 3304}
# {'_id': ObjectId('5c6e075279ec420f7dfc6a60'), 'from_station_id': 300, 'to_station_id': 100, 'trip_id': 17277301, 'from_station_name': 'Broadway & Barry Ave', 'to_station_name': 'Orleans St & Merchandise Mart Plaza', 'tripduration': 1296, 'usertype': 'Subscriber', 'bikeid': 3304}
# {'_id': ObjectId('5c6e075279ec420f7dfc81a7'), 'from_station_id': 127, 'to_station_id': 300, 'trip_id': 17270450, 'from_station_name': 'Lincoln Ave & Fullerton Ave', 'to_station_name': 'Broadway & Barry Ave', 'tripduration': 483, 'usertype': 'Subscriber', 'bikeid': 3304}
# ...
